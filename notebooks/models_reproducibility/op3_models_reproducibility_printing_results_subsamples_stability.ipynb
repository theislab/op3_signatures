# %%
import anndata as ad
import os
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Download results

# %%
def dict_to_pd(d):
    rows = []

    for outer_key, inner in d.items():
        row = {
            "dataset_id": inner["dataset_id"],
            "method_id": inner["method_id"],
        }
        
        # Use values from "d" as column names
        for col_name, value in zip(inner["metric_ids"], inner["metric_values"]):
            row[col_name] = value
            
        rows.append(row)
    
    df = pd.DataFrame(rows, index=d.keys())
    return df

# %%
methods_path = '../../data/benchmark/results/metrics/methods/'

# %%
os.listdir(methods_path + 'nn_retraining_with_pseudolabels_mol_emb_subsample_fp_trainable/stability')
# Out:
# ['seed_1', 'seed_2', 'seed_3', 'seed_4', 'seed_0']

# %%
file_name_err = 'mean_rowwise_error.h5ad'
file_name_corr = 'mean_rowwise_correlation.h5ad'

# %%
methods_err = {}
methods_corr = {}
for item in os.listdir(methods_path):
    if 'mol_emb_subsample' in item:
        stability_path = methods_path + item + '/stability'
        for seed in os.listdir(stability_path):
            
            err = ad.read_h5ad(f'{stability_path}/{seed}/{file_name_err}').uns
            corr = ad.read_h5ad(f'{stability_path}/{seed}/{file_name_corr}').uns
            methods_err[item + '_' + seed] = err
            methods_corr[item + '_' + seed] = corr

# %%
df_method_err = dict_to_pd(methods_err)

# %%
df_method_corr = dict_to_pd(methods_corr)

# %%
df_method_err['method_name'] = df_method_err.index.str.split('_seed_').str[0]
df_method_err['seed'] = df_method_err.index.str.split('_seed_').str[1].astype(int)

# %%
df_method_corr['method_name'] = df_method_corr.index.str.split('_seed_').str[0]
df_method_corr['seed'] = df_method_corr.index.str.split('_seed_').str[1].astype(int)

# %% [markdown]
# ## Mean rowwise error

# %% [markdown]
# ### Methods

# %%
df_method_err.sort_values(by="mean_rowwise_rmse")
# Out:
#                                                            dataset_id  \
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
#
#                                                                                             method_id  \
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_fp_con...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_lpm_tr...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...   nn_retraining_with_pseudolabels_mol_emb_fp_fixed
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_lpm_co...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_lpm_tr...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_lpm_tr...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_lpm_co...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...   nn_retraining_with_pseudolabels_mol_emb_fp_fixed
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_fp_con...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_fp_con...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_lpm_co...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_lpm_co...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_lpm_tr...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_lpm_co...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...   nn_retraining_with_pseudolabels_mol_emb_fp_fixed
# nn_retraining_with_pseudolabels_mol_emb_subsamp...   nn_retraining_with_pseudolabels_mol_emb_fp_fixed
# nn_retraining_with_pseudolabels_mol_emb_subsamp...   nn_retraining_with_pseudolabels_mol_emb_fp_fixed
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_fp_con...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_fp_con...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_fp_con...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_fp_con...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_fp_con...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_fp_tra...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_fp_tra...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_lpm_tr...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_fp_tra...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_fp_con...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_fp_tra...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_fp_con...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...       nn_retraining_with_pseudolabels_mol_emb_none
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_lpm_co...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_lpm_co...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_lpm_co...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_lpm_co...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_fp_tra...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_lpm_co...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...       nn_retraining_with_pseudolabels_mol_emb_none
# nn_retraining_with_pseudolabels_mol_emb_subsamp...       nn_retraining_with_pseudolabels_mol_emb_none
# nn_retraining_with_pseudolabels_mol_emb_subsamp...       nn_retraining_with_pseudolabels_mol_emb_none
# nn_retraining_with_pseudolabels_mol_emb_subsamp...       nn_retraining_with_pseudolabels_mol_emb_none
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_lpm_fixed
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_lpm_fixed
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_lpm_fixed
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_lpm_fixed
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_lpm_fixed
#
#                                                     mean_rowwise_rmse  \
# nn_retraining_with_pseudolabels_mol_emb_subsamp...           0.771154
# nn_retraining_with_pseudolabels_mol_emb_subsamp...           0.771371
# nn_retraining_with_pseudolabels_mol_emb_subsamp...           0.771421
# nn_retraining_with_pseudolabels_mol_emb_subsamp...           0.771755
# nn_retraining_with_pseudolabels_mol_emb_subsamp...           0.771808
# nn_retraining_with_pseudolabels_mol_emb_subsamp...           0.771888
# nn_retraining_with_pseudolabels_mol_emb_subsamp...           0.772528
# nn_retraining_with_pseudolabels_mol_emb_subsamp...           0.772942
# nn_retraining_with_pseudolabels_mol_emb_subsamp...           0.772965
# nn_retraining_with_pseudolabels_mol_emb_subsamp...           0.772966
# nn_retraining_with_pseudolabels_mol_emb_subsamp...           0.773078
# nn_retraining_with_pseudolabels_mol_emb_subsamp...           0.773319
# nn_retraining_with_pseudolabels_mol_emb_subsamp...           0.773399
# nn_retraining_with_pseudolabels_mol_emb_subsamp...           0.773626
# nn_retraining_with_pseudolabels_mol_emb_subsamp...           0.773709
# nn_retraining_with_pseudolabels_mol_emb_subsamp...           0.773786
# nn_retraining_with_pseudolabels_mol_emb_subsamp...           0.773859
# nn_retraining_with_pseudolabels_mol_emb_subsamp...           0.773910
# nn_retraining_with_pseudolabels_mol_emb_subsamp...           0.773925
# nn_retraining_with_pseudolabels_mol_emb_subsamp...           0.774014
# nn_retraining_with_pseudolabels_mol_emb_subsamp...           0.774071
# nn_retraining_with_pseudolabels_mol_emb_subsamp...           0.774357
# nn_retraining_with_pseudolabels_mol_emb_subsamp...           0.774431
# nn_retraining_with_pseudolabels_mol_emb_subsamp...           0.774447
# nn_retraining_with_pseudolabels_mol_emb_subsamp...           0.774467
# nn_retraining_with_pseudolabels_mol_emb_subsamp...           0.774697
# nn_retraining_with_pseudolabels_mol_emb_subsamp...           0.774697
# nn_retraining_with_pseudolabels_mol_emb_subsamp...           0.774766
# nn_retraining_with_pseudolabels_mol_emb_subsamp...           0.775192
# nn_retraining_with_pseudolabels_mol_emb_subsamp...           0.777277
# nn_retraining_with_pseudolabels_mol_emb_subsamp...           0.777793
# nn_retraining_with_pseudolabels_mol_emb_subsamp...           0.777853
# nn_retraining_with_pseudolabels_mol_emb_subsamp...           0.778808
# nn_retraining_with_pseudolabels_mol_emb_subsamp...           0.779035
# nn_retraining_with_pseudolabels_mol_emb_subsamp...           0.779060
# nn_retraining_with_pseudolabels_mol_emb_subsamp...           0.779726
# nn_retraining_with_pseudolabels_mol_emb_subsamp...           0.780244
# nn_retraining_with_pseudolabels_mol_emb_subsamp...           0.780762
# nn_retraining_with_pseudolabels_mol_emb_subsamp...           0.780872
# nn_retraining_with_pseudolabels_mol_emb_subsamp...           0.780907
# nn_retraining_with_pseudolabels_mol_emb_subsamp...           0.781098
# nn_retraining_with_pseudolabels_mol_emb_subsamp...           0.782176
# nn_retraining_with_pseudolabels_mol_emb_subsamp...           0.782495
# nn_retraining_with_pseudolabels_mol_emb_subsamp...           0.783277
# nn_retraining_with_pseudolabels_mol_emb_subsamp...           0.783351
#
#                                                     mean_rowwise_mae  \
# nn_retraining_with_pseudolabels_mol_emb_subsamp...          0.560883
# nn_retraining_with_pseudolabels_mol_emb_subsamp...          0.558549
# nn_retraining_with_pseudolabels_mol_emb_subsamp...          0.560991
# nn_retraining_with_pseudolabels_mol_emb_subsamp...          0.557349
# nn_retraining_with_pseudolabels_mol_emb_subsamp...          0.558389
# nn_retraining_with_pseudolabels_mol_emb_subsamp...          0.559362
# nn_retraining_with_pseudolabels_mol_emb_subsamp...          0.558035
# nn_retraining_with_pseudolabels_mol_emb_subsamp...          0.562111
# nn_retraining_with_pseudolabels_mol_emb_subsamp...          0.561934
# nn_retraining_with_pseudolabels_mol_emb_subsamp...          0.562632
# nn_retraining_with_pseudolabels_mol_emb_subsamp...          0.558334
# nn_retraining_with_pseudolabels_mol_emb_subsamp...          0.558629
# nn_retraining_with_pseudolabels_mol_emb_subsamp...          0.559782
# nn_retraining_with_pseudolabels_mol_emb_subsamp...          0.558833
# nn_retraining_with_pseudolabels_mol_emb_subsamp...          0.563265
# nn_retraining_with_pseudolabels_mol_emb_subsamp...          0.563549
# nn_retraining_with_pseudolabels_mol_emb_subsamp...          0.562701
# nn_retraining_with_pseudolabels_mol_emb_subsamp...          0.563035
# nn_retraining_with_pseudolabels_mol_emb_subsamp...          0.559392
# nn_retraining_with_pseudolabels_mol_emb_subsamp...          0.560045
# nn_retraining_with_pseudolabels_mol_emb_subsamp...          0.559148
# nn_retraining_with_pseudolabels_mol_emb_subsamp...          0.563863
# nn_retraining_with_pseudolabels_mol_emb_subsamp...          0.563077
# nn_retraining_with_pseudolabels_mol_emb_subsamp...          0.563246
# nn_retraining_with_pseudolabels_mol_emb_subsamp...          0.561069
# nn_retraining_with_pseudolabels_mol_emb_subsamp...          0.563237
# nn_retraining_with_pseudolabels_mol_emb_subsamp...          0.560117
# nn_retraining_with_pseudolabels_mol_emb_subsamp...          0.563483
# nn_retraining_with_pseudolabels_mol_emb_subsamp...          0.560043
# nn_retraining_with_pseudolabels_mol_emb_subsamp...          0.555428
# nn_retraining_with_pseudolabels_mol_emb_subsamp...          0.558065
# nn_retraining_with_pseudolabels_mol_emb_subsamp...          0.557888
# nn_retraining_with_pseudolabels_mol_emb_subsamp...          0.558090
# nn_retraining_with_pseudolabels_mol_emb_subsamp...          0.558318
# nn_retraining_with_pseudolabels_mol_emb_subsamp...          0.566604
# nn_retraining_with_pseudolabels_mol_emb_subsamp...          0.558894
# nn_retraining_with_pseudolabels_mol_emb_subsamp...          0.556656
# nn_retraining_with_pseudolabels_mol_emb_subsamp...          0.557350
# nn_retraining_with_pseudolabels_mol_emb_subsamp...          0.556986
# nn_retraining_with_pseudolabels_mol_emb_subsamp...          0.557612
# nn_retraining_with_pseudolabels_mol_emb_subsamp...          0.560511
# nn_retraining_with_pseudolabels_mol_emb_subsamp...          0.561141
# nn_retraining_with_pseudolabels_mol_emb_subsamp...          0.561267
# nn_retraining_with_pseudolabels_mol_emb_subsamp...          0.561864
# nn_retraining_with_pseudolabels_mol_emb_subsamp...          0.561434
#
#                                                                                           method_name  \
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
#
#                                                     seed
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     0
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     1
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     1
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     0
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     2
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     0
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     1
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     3
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     3
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     1
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     3
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     4
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     3
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     2
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     0
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     4
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     2
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     2
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     0
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     4
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     3
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     4
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     2
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     0
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     4
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     3
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     1
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     1
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     2
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     0
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     4
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     0
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     3
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     2
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     4
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     1
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     3
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     1
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     2
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     4
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     0
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     2
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     1
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     4
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     3

# %%
metrics = ["mean_rowwise_rmse", "mean_rowwise_mae"]
fig, axes = plt.subplots(1, len(metrics), figsize=(6 * len(metrics), 5))
for ax, metric in zip(axes, metrics):
    # collect values per method, ordered by median
    methods_ordered = (
        df_method_err.groupby("method_name")[metric]
        .median()
        .sort_values()
        .index.tolist()
    )
    data_per_method = [
        df_method_err.loc[df_method_err["method_name"] == m, metric].values
        for m in methods_ordered
    ]
    bp = ax.boxplot(data_per_method, patch_artist=True, vert=True)
    ax.set_xticks(range(1, len(methods_ordered) + 1))
    ax.set_xticklabels(
        # strip the long common prefix for readability
        [m.replace("nn_retraining_with_pseudolabels_mol_emb_subsample_", "") for m in methods_ordered],
        rotation=45, ha="right", fontsize=8,
    )
    ax.set_ylabel(metric)
    ax.set_title(metric)
    ax.grid(axis="y", linestyle="--", alpha=0.5)
fig.suptitle("Stability across seeds", fontsize=13, y=1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Mean rowwise correlation

# %% [markdown]
# ### Methods

# %%
df_method_corr.sort_values(by="mean_rowwise_pearson", ascending=False)
#df_method_corr.sort_values(by="mean_rowwise_spearman", ascending=False)
# Out:
#                                                            dataset_id  \
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
#
#                                                                                             method_id  \
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_lpm_tr...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_lpm_tr...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_lpm_tr...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_lpm_tr...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_fp_tra...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_fp_tra...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_lpm_tr...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_fp_tra...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_fp_tra...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_fp_tra...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...       nn_retraining_with_pseudolabels_mol_emb_none
# nn_retraining_with_pseudolabels_mol_emb_subsamp...       nn_retraining_with_pseudolabels_mol_emb_none
# nn_retraining_with_pseudolabels_mol_emb_subsamp...       nn_retraining_with_pseudolabels_mol_emb_none
# nn_retraining_with_pseudolabels_mol_emb_subsamp...       nn_retraining_with_pseudolabels_mol_emb_none
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_lpm_co...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...       nn_retraining_with_pseudolabels_mol_emb_none
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_lpm_co...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...   nn_retraining_with_pseudolabels_mol_emb_fp_fixed
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_lpm_co...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_lpm_co...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...   nn_retraining_with_pseudolabels_mol_emb_fp_fixed
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_fp_con...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_lpm_co...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...   nn_retraining_with_pseudolabels_mol_emb_fp_fixed
# nn_retraining_with_pseudolabels_mol_emb_subsamp...   nn_retraining_with_pseudolabels_mol_emb_fp_fixed
# nn_retraining_with_pseudolabels_mol_emb_subsamp...   nn_retraining_with_pseudolabels_mol_emb_fp_fixed
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_lpm_co...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_lpm_co...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_lpm_co...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_fp_con...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_fp_con...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_fp_con...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_fp_con...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_lpm_co...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_lpm_co...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_lpm_fixed
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_fp_con...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_lpm_fixed
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_lpm_fixed
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_lpm_fixed
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_lpm_fixed
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_fp_con...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_fp_con...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_fp_con...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_fp_con...
#
#                                                     mean_rowwise_pearson  \
# nn_retraining_with_pseudolabels_mol_emb_subsamp...              0.494524
# nn_retraining_with_pseudolabels_mol_emb_subsamp...              0.494247
# nn_retraining_with_pseudolabels_mol_emb_subsamp...              0.494070
# nn_retraining_with_pseudolabels_mol_emb_subsamp...              0.493912
# nn_retraining_with_pseudolabels_mol_emb_subsamp...              0.493030
# nn_retraining_with_pseudolabels_mol_emb_subsamp...              0.492930
# nn_retraining_with_pseudolabels_mol_emb_subsamp...              0.492842
# nn_retraining_with_pseudolabels_mol_emb_subsamp...              0.492648
# nn_retraining_with_pseudolabels_mol_emb_subsamp...              0.492210
# nn_retraining_with_pseudolabels_mol_emb_subsamp...              0.491106
# nn_retraining_with_pseudolabels_mol_emb_subsamp...              0.489732
# nn_retraining_with_pseudolabels_mol_emb_subsamp...              0.489728
# nn_retraining_with_pseudolabels_mol_emb_subsamp...              0.489474
# nn_retraining_with_pseudolabels_mol_emb_subsamp...              0.489272
# nn_retraining_with_pseudolabels_mol_emb_subsamp...              0.488609
# nn_retraining_with_pseudolabels_mol_emb_subsamp...              0.488389
# nn_retraining_with_pseudolabels_mol_emb_subsamp...              0.488234
# nn_retraining_with_pseudolabels_mol_emb_subsamp...              0.487525
# nn_retraining_with_pseudolabels_mol_emb_subsamp...              0.487345
# nn_retraining_with_pseudolabels_mol_emb_subsamp...              0.487194
# nn_retraining_with_pseudolabels_mol_emb_subsamp...              0.487141
# nn_retraining_with_pseudolabels_mol_emb_subsamp...              0.487048
# nn_retraining_with_pseudolabels_mol_emb_subsamp...              0.486853
# nn_retraining_with_pseudolabels_mol_emb_subsamp...              0.486799
# nn_retraining_with_pseudolabels_mol_emb_subsamp...              0.486369
# nn_retraining_with_pseudolabels_mol_emb_subsamp...              0.485709
# nn_retraining_with_pseudolabels_mol_emb_subsamp...              0.485614
# nn_retraining_with_pseudolabels_mol_emb_subsamp...              0.485144
# nn_retraining_with_pseudolabels_mol_emb_subsamp...              0.485136
# nn_retraining_with_pseudolabels_mol_emb_subsamp...              0.485065
# nn_retraining_with_pseudolabels_mol_emb_subsamp...              0.484742
# nn_retraining_with_pseudolabels_mol_emb_subsamp...              0.484414
# nn_retraining_with_pseudolabels_mol_emb_subsamp...              0.484293
# nn_retraining_with_pseudolabels_mol_emb_subsamp...              0.484264
# nn_retraining_with_pseudolabels_mol_emb_subsamp...              0.483907
# nn_retraining_with_pseudolabels_mol_emb_subsamp...              0.481668
# nn_retraining_with_pseudolabels_mol_emb_subsamp...              0.481005
# nn_retraining_with_pseudolabels_mol_emb_subsamp...              0.480988
# nn_retraining_with_pseudolabels_mol_emb_subsamp...              0.480903
# nn_retraining_with_pseudolabels_mol_emb_subsamp...              0.480855
# nn_retraining_with_pseudolabels_mol_emb_subsamp...              0.480611
# nn_retraining_with_pseudolabels_mol_emb_subsamp...              0.479781
# nn_retraining_with_pseudolabels_mol_emb_subsamp...              0.479207
# nn_retraining_with_pseudolabels_mol_emb_subsamp...              0.478883
# nn_retraining_with_pseudolabels_mol_emb_subsamp...              0.477148
#
#                                                     mean_rowwise_spearman  \
# nn_retraining_with_pseudolabels_mol_emb_subsamp...               0.464688
# nn_retraining_with_pseudolabels_mol_emb_subsamp...               0.464443
# nn_retraining_with_pseudolabels_mol_emb_subsamp...               0.464636
# nn_retraining_with_pseudolabels_mol_emb_subsamp...               0.463809
# nn_retraining_with_pseudolabels_mol_emb_subsamp...               0.462767
# nn_retraining_with_pseudolabels_mol_emb_subsamp...               0.462927
# nn_retraining_with_pseudolabels_mol_emb_subsamp...               0.462902
# nn_retraining_with_pseudolabels_mol_emb_subsamp...               0.462214
# nn_retraining_with_pseudolabels_mol_emb_subsamp...               0.462128
# nn_retraining_with_pseudolabels_mol_emb_subsamp...               0.460547
# nn_retraining_with_pseudolabels_mol_emb_subsamp...               0.461598
# nn_retraining_with_pseudolabels_mol_emb_subsamp...               0.461660
# nn_retraining_with_pseudolabels_mol_emb_subsamp...               0.461097
# nn_retraining_with_pseudolabels_mol_emb_subsamp...               0.460868
# nn_retraining_with_pseudolabels_mol_emb_subsamp...               0.459993
# nn_retraining_with_pseudolabels_mol_emb_subsamp...               0.460500
# nn_retraining_with_pseudolabels_mol_emb_subsamp...               0.459389
# nn_retraining_with_pseudolabels_mol_emb_subsamp...               0.458675
# nn_retraining_with_pseudolabels_mol_emb_subsamp...               0.458814
# nn_retraining_with_pseudolabels_mol_emb_subsamp...               0.458030
# nn_retraining_with_pseudolabels_mol_emb_subsamp...               0.458138
# nn_retraining_with_pseudolabels_mol_emb_subsamp...               0.458004
# nn_retraining_with_pseudolabels_mol_emb_subsamp...               0.458119
# nn_retraining_with_pseudolabels_mol_emb_subsamp...               0.458069
# nn_retraining_with_pseudolabels_mol_emb_subsamp...               0.457081
# nn_retraining_with_pseudolabels_mol_emb_subsamp...               0.457069
# nn_retraining_with_pseudolabels_mol_emb_subsamp...               0.457912
# nn_retraining_with_pseudolabels_mol_emb_subsamp...               0.457413
# nn_retraining_with_pseudolabels_mol_emb_subsamp...               0.457711
# nn_retraining_with_pseudolabels_mol_emb_subsamp...               0.456075
# nn_retraining_with_pseudolabels_mol_emb_subsamp...               0.455465
# nn_retraining_with_pseudolabels_mol_emb_subsamp...               0.454871
# nn_retraining_with_pseudolabels_mol_emb_subsamp...               0.455038
# nn_retraining_with_pseudolabels_mol_emb_subsamp...               0.456133
# nn_retraining_with_pseudolabels_mol_emb_subsamp...               0.456121
# nn_retraining_with_pseudolabels_mol_emb_subsamp...               0.454250
# nn_retraining_with_pseudolabels_mol_emb_subsamp...               0.453257
# nn_retraining_with_pseudolabels_mol_emb_subsamp...               0.453535
# nn_retraining_with_pseudolabels_mol_emb_subsamp...               0.453486
# nn_retraining_with_pseudolabels_mol_emb_subsamp...               0.453052
# nn_retraining_with_pseudolabels_mol_emb_subsamp...               0.453144
# nn_retraining_with_pseudolabels_mol_emb_subsamp...               0.452064
# nn_retraining_with_pseudolabels_mol_emb_subsamp...               0.451391
# nn_retraining_with_pseudolabels_mol_emb_subsamp...               0.451099
# nn_retraining_with_pseudolabels_mol_emb_subsamp...               0.449491
#
#                                                     mean_rowwise_cosine  \
# nn_retraining_with_pseudolabels_mol_emb_subsamp...             0.497521
# nn_retraining_with_pseudolabels_mol_emb_subsamp...             0.497263
# nn_retraining_with_pseudolabels_mol_emb_subsamp...             0.497025
# nn_retraining_with_pseudolabels_mol_emb_subsamp...             0.496961
# nn_retraining_with_pseudolabels_mol_emb_subsamp...             0.495960
# nn_retraining_with_pseudolabels_mol_emb_subsamp...             0.495848
# nn_retraining_with_pseudolabels_mol_emb_subsamp...             0.495819
# nn_retraining_with_pseudolabels_mol_emb_subsamp...             0.495599
# nn_retraining_with_pseudolabels_mol_emb_subsamp...             0.495175
# nn_retraining_with_pseudolabels_mol_emb_subsamp...             0.494079
# nn_retraining_with_pseudolabels_mol_emb_subsamp...             0.493010
# nn_retraining_with_pseudolabels_mol_emb_subsamp...             0.493012
# nn_retraining_with_pseudolabels_mol_emb_subsamp...             0.492809
# nn_retraining_with_pseudolabels_mol_emb_subsamp...             0.492562
# nn_retraining_with_pseudolabels_mol_emb_subsamp...             0.491658
# nn_retraining_with_pseudolabels_mol_emb_subsamp...             0.491704
# nn_retraining_with_pseudolabels_mol_emb_subsamp...             0.491248
# nn_retraining_with_pseudolabels_mol_emb_subsamp...             0.490600
# nn_retraining_with_pseudolabels_mol_emb_subsamp...             0.490369
# nn_retraining_with_pseudolabels_mol_emb_subsamp...             0.490239
# nn_retraining_with_pseudolabels_mol_emb_subsamp...             0.490305
# nn_retraining_with_pseudolabels_mol_emb_subsamp...             0.490098
# nn_retraining_with_pseudolabels_mol_emb_subsamp...             0.489866
# nn_retraining_with_pseudolabels_mol_emb_subsamp...             0.489965
# nn_retraining_with_pseudolabels_mol_emb_subsamp...             0.489533
# nn_retraining_with_pseudolabels_mol_emb_subsamp...             0.488795
# nn_retraining_with_pseudolabels_mol_emb_subsamp...             0.488862
# nn_retraining_with_pseudolabels_mol_emb_subsamp...             0.488382
# nn_retraining_with_pseudolabels_mol_emb_subsamp...             0.488316
# nn_retraining_with_pseudolabels_mol_emb_subsamp...             0.488158
# nn_retraining_with_pseudolabels_mol_emb_subsamp...             0.487810
# nn_retraining_with_pseudolabels_mol_emb_subsamp...             0.487499
# nn_retraining_with_pseudolabels_mol_emb_subsamp...             0.487352
# nn_retraining_with_pseudolabels_mol_emb_subsamp...             0.487516
# nn_retraining_with_pseudolabels_mol_emb_subsamp...             0.487125
# nn_retraining_with_pseudolabels_mol_emb_subsamp...             0.484898
# nn_retraining_with_pseudolabels_mol_emb_subsamp...             0.484192
# nn_retraining_with_pseudolabels_mol_emb_subsamp...             0.484185
# nn_retraining_with_pseudolabels_mol_emb_subsamp...             0.484099
# nn_retraining_with_pseudolabels_mol_emb_subsamp...             0.484074
# nn_retraining_with_pseudolabels_mol_emb_subsamp...             0.483830
# nn_retraining_with_pseudolabels_mol_emb_subsamp...             0.483012
# nn_retraining_with_pseudolabels_mol_emb_subsamp...             0.482420
# nn_retraining_with_pseudolabels_mol_emb_subsamp...             0.482030
# nn_retraining_with_pseudolabels_mol_emb_subsamp...             0.480353
#
#                                                                                           method_name  \
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
#
#                                                     seed
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     0
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     4
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     2
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     1
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     0
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     2
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     3
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     3
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     4
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     1
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     0
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     2
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     1
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     3
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     4
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     4
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     0
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     0
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     2
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     1
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     3
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     0
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     3
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     4
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     1
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     2
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     4
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     0
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     2
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     4
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     3
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     1
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     2
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     3
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     1
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     4
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     0
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     3
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     0
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     1
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     2
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     4
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     3
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     2
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     1

# %%
corr_metrics = ["mean_rowwise_pearson", "mean_rowwise_spearman", "mean_rowwise_cosine"]
fig, axes = plt.subplots(1, len(corr_metrics), figsize=(6 * len(corr_metrics), 5))
for ax, metric in zip(axes, corr_metrics):
    # higher correlation is better → sort descending
    methods_ordered = (
        df_method_corr.groupby("method_name")[metric]
        .median()
        .sort_values(ascending=False)
        .index.tolist()
    )
    data_per_method = [
        df_method_corr.loc[df_method_corr["method_name"] == m, metric].values
        for m in methods_ordered
    ]
    bp = ax.boxplot(data_per_method, patch_artist=True, vert=True)
    ax.set_xticks(range(1, len(methods_ordered) + 1))
    ax.set_xticklabels(
        [m.replace("nn_retraining_with_pseudolabels_mol_emb_subsample_", "") for m in methods_ordered],
        rotation=45, ha="right", fontsize=8,
    )
    ax.set_ylabel(metric)
    ax.set_title(metric)
    ax.grid(axis="y", linestyle="--", alpha=0.5)
fig.suptitle("Stability across seeds — correlations", fontsize=13, y=1.02)
plt.tight_layout()
plt.show()
