# %%
import anndata as ad
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %% [markdown]
# ## Download results

# %%
def dict_to_pd(d):
    rows = []

    for outer_key, inner in d.items():
        row = {
            "dataset_id": inner["dataset_id"],
            "method_id": inner["method_id"],
        }
        
        # Use values from "d" as column names
        for col_name, value in zip(inner["metric_ids"], inner["metric_values"]):
            row[col_name] = value
            
        rows.append(row)
    
    df = pd.DataFrame(rows, index=d.keys())
    return df

# %%
methods_path = '../../data_lpm_style_learning_missed/benchmark/results/metrics/methods/'

# %%
os.listdir(methods_path + 'nn_retraining_with_pseudolabels_mol_emb_learning_missed_subsample_lpm_concat_dense_all_10/stability')
# Out:
# ['seed_10',
#  'seed_11',
#  'seed_4',
#  'seed_3',
#  'seed_14',
#  'seed_1',
#  'seed_2',
#  'seed_12',
#  'seed_0',
#  'seed_13']

# %%
file_name_err = 'mean_rowwise_error.h5ad'
file_name_corr = 'mean_rowwise_correlation.h5ad'

# %%
methods_err = {}
methods_corr = {}
for item in os.listdir(methods_path):
    if 'mol_emb_learning' in item:
        if 'nn_retraining_with_pseudolabels_mol_emb_subsample_fp' in item:
            name = item.replace('_all_1', '')
        else:
            name = item
        name = name.replace('nn_retraining_with_pseudolabels_mol_emb_learning_missed_subsample_', '')
        stability_path = methods_path + item + '/stability'
        for seed in os.listdir(stability_path):
            
            err = ad.read_h5ad(f'{stability_path}/{seed}/{file_name_err}').uns
            corr = ad.read_h5ad(f'{stability_path}/{seed}/{file_name_corr}').uns
            methods_err[name + '_' + seed] = err
            methods_corr[name + '_' + seed] = corr

# %%
df_method_err = dict_to_pd(methods_err)

# %%
df_method_corr = dict_to_pd(methods_corr)

# %%
df_method_err['method_name'] = df_method_err.index.str.split('_seed_').str[0]
df_method_err['seed'] = df_method_err.index.str.split('_seed_').str[1].astype(int)

# %%
df_method_corr['method_name'] = df_method_corr.index.str.split('_seed_').str[0]
df_method_corr['seed'] = df_method_corr.index.str.split('_seed_').str[1].astype(int)

# %%
len(df_method_corr['method_name'].unique())
# Out:
# 37

# %% [markdown]
# ## Mean rowwise error

# %% [markdown]
# ### Methods

# %%
df_method_err.sort_values(by="mean_rowwise_rmse")
# Out:
#                                      dataset_id  \
# lpm_trainable_all_20_seed_10  neurips-2023-data
# lpm_trainable_all_20_seed_1   neurips-2023-data
# lpm_trainable_all_20_seed_13  neurips-2023-data
# lpm_trainable_all_20_seed_4   neurips-2023-data
# lpm_trainable_all_20_seed_12  neurips-2023-data
# ...                                         ...
# lpm_fixed_all_25_seed_0       neurips-2023-data
# lpm_fixed_all_25_seed_13      neurips-2023-data
# lpm_fixed_all_25_seed_3       neurips-2023-data
# lpm_fixed_all_25_seed_12      neurips-2023-data
# lpm_fixed_all_25_seed_10      neurips-2023-data
#
#                                                                       method_id  \
# lpm_trainable_all_20_seed_10  nn_retraining_with_pseudolabels_mol_emb_lpm_tr...
# lpm_trainable_all_20_seed_1   nn_retraining_with_pseudolabels_mol_emb_lpm_tr...
# lpm_trainable_all_20_seed_13  nn_retraining_with_pseudolabels_mol_emb_lpm_tr...
# lpm_trainable_all_20_seed_4   nn_retraining_with_pseudolabels_mol_emb_lpm_tr...
# lpm_trainable_all_20_seed_12  nn_retraining_with_pseudolabels_mol_emb_lpm_tr...
# ...                                                                         ...
# lpm_fixed_all_25_seed_0       nn_retraining_with_pseudolabels_mol_emb_lpm_fixed
# lpm_fixed_all_25_seed_13      nn_retraining_with_pseudolabels_mol_emb_lpm_fixed
# lpm_fixed_all_25_seed_3       nn_retraining_with_pseudolabels_mol_emb_lpm_fixed
# lpm_fixed_all_25_seed_12      nn_retraining_with_pseudolabels_mol_emb_lpm_fixed
# lpm_fixed_all_25_seed_10      nn_retraining_with_pseudolabels_mol_emb_lpm_fixed
#
#                               mean_rowwise_rmse  mean_rowwise_mae  \
# lpm_trainable_all_20_seed_10           0.802382          0.566639
# lpm_trainable_all_20_seed_1            0.802922          0.567278
# lpm_trainable_all_20_seed_13           0.802923          0.567252
# lpm_trainable_all_20_seed_4            0.803084          0.566383
# lpm_trainable_all_20_seed_12           0.803332          0.567428
# ...                                         ...               ...
# lpm_fixed_all_25_seed_0                0.878966          0.632481
# lpm_fixed_all_25_seed_13               0.879025          0.632114
# lpm_fixed_all_25_seed_3                0.879526          0.632689
# lpm_fixed_all_25_seed_12               0.880774          0.633147
# lpm_fixed_all_25_seed_10               0.885870          0.638061
#
#                                        method_name  seed
# lpm_trainable_all_20_seed_10  lpm_trainable_all_20    10
# lpm_trainable_all_20_seed_1   lpm_trainable_all_20     1
# lpm_trainable_all_20_seed_13  lpm_trainable_all_20    13
# lpm_trainable_all_20_seed_4   lpm_trainable_all_20     4
# lpm_trainable_all_20_seed_12  lpm_trainable_all_20    12
# ...                                            ...   ...
# lpm_fixed_all_25_seed_0           lpm_fixed_all_25     0
# lpm_fixed_all_25_seed_13          lpm_fixed_all_25    13
# lpm_fixed_all_25_seed_3           lpm_fixed_all_25     3
# lpm_fixed_all_25_seed_12          lpm_fixed_all_25    12
# lpm_fixed_all_25_seed_10          lpm_fixed_all_25    10
#
# [370 rows x 6 columns]

# %%
df_method_err
# Out:
#                                             dataset_id  \
# lpm_concat_not_dense_all_25_seed_12  neurips-2023-data
# lpm_concat_not_dense_all_25_seed_2   neurips-2023-data
# lpm_concat_not_dense_all_25_seed_14  neurips-2023-data
# lpm_concat_not_dense_all_25_seed_10  neurips-2023-data
# lpm_concat_not_dense_all_25_seed_3   neurips-2023-data
# ...                                                ...
# fp_fixed_fp_seed_10                  neurips-2023-data
# fp_fixed_fp_seed_0                   neurips-2023-data
# fp_fixed_fp_seed_3                   neurips-2023-data
# fp_fixed_fp_seed_11                  neurips-2023-data
# fp_fixed_fp_seed_2                   neurips-2023-data
#
#                                                                              method_id  \
# lpm_concat_not_dense_all_25_seed_12  nn_retraining_with_pseudolabels_mol_emb_lpm_co...
# lpm_concat_not_dense_all_25_seed_2   nn_retraining_with_pseudolabels_mol_emb_lpm_co...
# lpm_concat_not_dense_all_25_seed_14  nn_retraining_with_pseudolabels_mol_emb_lpm_co...
# lpm_concat_not_dense_all_25_seed_10  nn_retraining_with_pseudolabels_mol_emb_lpm_co...
# lpm_concat_not_dense_all_25_seed_3   nn_retraining_with_pseudolabels_mol_emb_lpm_co...
# ...                                                                                ...
# fp_fixed_fp_seed_10                   nn_retraining_with_pseudolabels_mol_emb_fp_fixed
# fp_fixed_fp_seed_0                    nn_retraining_with_pseudolabels_mol_emb_fp_fixed
# fp_fixed_fp_seed_3                    nn_retraining_with_pseudolabels_mol_emb_fp_fixed
# fp_fixed_fp_seed_11                   nn_retraining_with_pseudolabels_mol_emb_fp_fixed
# fp_fixed_fp_seed_2                    nn_retraining_with_pseudolabels_mol_emb_fp_fixed
#
#                                      mean_rowwise_rmse  mean_rowwise_mae  \
# lpm_concat_not_dense_all_25_seed_12           0.817255          0.577408
# lpm_concat_not_dense_all_25_seed_2            0.818331          0.578670
# lpm_concat_not_dense_all_25_seed_14           0.816970          0.576908
# lpm_concat_not_dense_all_25_seed_10           0.818126          0.577890
# lpm_concat_not_dense_all_25_seed_3            0.817832          0.577472
# ...                                                ...               ...
# fp_fixed_fp_seed_10                           0.853340          0.613277
# fp_fixed_fp_seed_0                            0.857795          0.617237
# fp_fixed_fp_seed_3                            0.853087          0.612107
# fp_fixed_fp_seed_11                           0.855590          0.614676
# fp_fixed_fp_seed_2                            0.856064          0.615645
#
#                                                      method_name  seed
# lpm_concat_not_dense_all_25_seed_12  lpm_concat_not_dense_all_25    12
# lpm_concat_not_dense_all_25_seed_2   lpm_concat_not_dense_all_25     2
# lpm_concat_not_dense_all_25_seed_14  lpm_concat_not_dense_all_25    14
# lpm_concat_not_dense_all_25_seed_10  lpm_concat_not_dense_all_25    10
# lpm_concat_not_dense_all_25_seed_3   lpm_concat_not_dense_all_25     3
# ...                                                          ...   ...
# fp_fixed_fp_seed_10                                  fp_fixed_fp    10
# fp_fixed_fp_seed_0                                   fp_fixed_fp     0
# fp_fixed_fp_seed_3                                   fp_fixed_fp     3
# fp_fixed_fp_seed_11                                  fp_fixed_fp    11
# fp_fixed_fp_seed_2                                   fp_fixed_fp     2
#
# [370 rows x 6 columns]

# %%
metrics = ["mean_rowwise_rmse", "mean_rowwise_mae"]
#fig, axes = plt.subplots(1, len(metrics), figsize=(6 * len(metrics), 5))
for metric in metrics:
    # collect values per method, ordered by median
    methods_ordered = (
        df_method_err.groupby("method_name")[metric]
        .median()
        .sort_values()
        .index.tolist()
    )
    data_per_method = [
        df_method_err.loc[df_method_err["method_name"] == m, metric].values
        for m in methods_ordered
    ]
    plt.figure(figsize=(20, 5))
    plt.boxplot(data_per_method, patch_artist=True, vert=True)
    plt.xticks(
        range(1, len(methods_ordered) + 1),
        # strip the long common prefix for readability
        [m.replace("nn_retraining_with_pseudolabels_mol_emb_subsample_", "") for m in methods_ordered],
        rotation=45, ha="right", fontsize=8,
    )
    plt.ylabel(metric)
    plt.title(metric)
    plt.grid(axis="y", linestyle="--", alpha=0.5)
    plt.show()
#fig.suptitle("Stability across seeds", fontsize=13, y=1.02)
#plt.tight_layout()

# %% [markdown]
# ## Mean rowwise correlation

# %% [markdown]
# ### Methods

# %%
df_method_corr.sort_values(by="mean_rowwise_pearson", ascending=False)
#df_method_corr.sort_values(by="mean_rowwise_spearman", ascending=False)
# Out:
#                                      dataset_id  \
# lpm_trainable_all_15_seed_4   neurips-2023-data
# lpm_trainable_all_15_seed_0   neurips-2023-data
# lpm_trainable_all_20_seed_1   neurips-2023-data
# lpm_trainable_all_15_seed_12  neurips-2023-data
# lpm_trainable_all_15_seed_2   neurips-2023-data
# ...                                         ...
# lpm_fixed_all_25_seed_11      neurips-2023-data
# lpm_fixed_all_25_seed_12      neurips-2023-data
# lpm_fixed_all_25_seed_13      neurips-2023-data
# lpm_fixed_l1000_15_seed_11    neurips-2023-data
# lpm_fixed_all_15_seed_11      neurips-2023-data
#
#                                                                       method_id  \
# lpm_trainable_all_15_seed_4   nn_retraining_with_pseudolabels_mol_emb_lpm_tr...
# lpm_trainable_all_15_seed_0   nn_retraining_with_pseudolabels_mol_emb_lpm_tr...
# lpm_trainable_all_20_seed_1   nn_retraining_with_pseudolabels_mol_emb_lpm_tr...
# lpm_trainable_all_15_seed_12  nn_retraining_with_pseudolabels_mol_emb_lpm_tr...
# lpm_trainable_all_15_seed_2   nn_retraining_with_pseudolabels_mol_emb_lpm_tr...
# ...                                                                         ...
# lpm_fixed_all_25_seed_11      nn_retraining_with_pseudolabels_mol_emb_lpm_fixed
# lpm_fixed_all_25_seed_12      nn_retraining_with_pseudolabels_mol_emb_lpm_fixed
# lpm_fixed_all_25_seed_13      nn_retraining_with_pseudolabels_mol_emb_lpm_fixed
# lpm_fixed_l1000_15_seed_11    nn_retraining_with_pseudolabels_mol_emb_lpm_fixed
# lpm_fixed_all_15_seed_11      nn_retraining_with_pseudolabels_mol_emb_lpm_fixed
#
#                               mean_rowwise_pearson  mean_rowwise_spearman  \
# lpm_trainable_all_15_seed_4               0.288204               0.277027
# lpm_trainable_all_15_seed_0               0.288038               0.276683
# lpm_trainable_all_20_seed_1               0.287489               0.275914
# lpm_trainable_all_15_seed_12              0.287441               0.275562
# lpm_trainable_all_15_seed_2               0.287421               0.276341
# ...                                            ...                    ...
# lpm_fixed_all_25_seed_11                  0.226995               0.215191
# lpm_fixed_all_25_seed_12                  0.226822               0.215379
# lpm_fixed_all_25_seed_13                  0.226392               0.215085
# lpm_fixed_l1000_15_seed_11                0.226380               0.214098
# lpm_fixed_all_15_seed_11                  0.226270               0.216435
#
#                               mean_rowwise_cosine           method_name  seed
# lpm_trainable_all_15_seed_4              0.292207  lpm_trainable_all_15     4
# lpm_trainable_all_15_seed_0              0.291921  lpm_trainable_all_15     0
# lpm_trainable_all_20_seed_1              0.291325  lpm_trainable_all_20     1
# lpm_trainable_all_15_seed_12             0.291394  lpm_trainable_all_15    12
# lpm_trainable_all_15_seed_2              0.291330  lpm_trainable_all_15     2
# ...                                           ...                   ...   ...
# lpm_fixed_all_25_seed_11                 0.230614      lpm_fixed_all_25    11
# lpm_fixed_all_25_seed_12                 0.230387      lpm_fixed_all_25    12
# lpm_fixed_all_25_seed_13                 0.229948      lpm_fixed_all_25    13
# lpm_fixed_l1000_15_seed_11               0.230643    lpm_fixed_l1000_15    11
# lpm_fixed_all_15_seed_11                 0.230287      lpm_fixed_all_15    11
#
# [370 rows x 7 columns]

# %%
corr_metrics = ["mean_rowwise_pearson", "mean_rowwise_spearman", "mean_rowwise_cosine"]
for metric in corr_metrics:
    # higher correlation is better → sort descending
    methods_ordered = (
        df_method_corr.groupby("method_name")[metric]
        .median()
        .sort_values(ascending=False)
        .index.tolist()
    )
    data_per_method = [
        df_method_corr.loc[df_method_corr["method_name"] == m, metric].values
        for m in methods_ordered
    ]
    plt.figure(figsize=(20, 5))
    plt.boxplot(data_per_method, patch_artist=True, vert=True)
    plt.boxplot(data_per_method, patch_artist=True, vert=True)

    plt.xticks(
        range(1, len(methods_ordered) + 1),
        [m.replace("nn_retraining_with_pseudolabels_mol_emb_subsample_", "") for m in methods_ordered],
        rotation=45, ha="right", fontsize=8,
    )
    plt.ylabel(metric)
    plt.title(metric)
    plt.grid(axis="y", linestyle="--", alpha=0.5)

    plt.show()
