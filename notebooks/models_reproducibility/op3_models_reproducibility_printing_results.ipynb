# %%
import anndata as ad
import os
import pandas as pd

# %% [markdown]
# ## Download results

# %%
def dict_to_pd(d):
    rows = []

    for outer_key, inner in d.items():
        row = {
            "dataset_id": inner["dataset_id"],
            "method_id": inner["method_id"],
        }
        
        # Use values from "d" as column names
        for col_name, value in zip(inner["metric_ids"], inner["metric_values"]):
            row[col_name] = value
            
        rows.append(row)
    
    df = pd.DataFrame(rows, index=d.keys())
    return df

# %%
control_path = '../data/benchmark/results/metrics/control_methods/'
methods_path = '../data/benchmark/results/metrics/methods/'

# %%
file_name_err = 'mean_rowwise_error.h5ad'
file_name_corr = 'mean_rowwise_correlation.h5ad'

# %%
methods_err = {}
methods_corr = {}
for item in os.listdir(methods_path):
    err = ad.read_h5ad(f'{methods_path}{item}/{file_name_err}').uns
    corr = ad.read_h5ad(f'{methods_path}{item}/{file_name_corr}').uns
    methods_err[item] = err
    methods_corr[item] = corr

# %%
control_err = {}
control_corr = {}
for item in os.listdir(control_path):
    err = ad.read_h5ad(f'{control_path}{item}/{file_name_err}').uns
    corr = ad.read_h5ad(f'{control_path}{item}/{file_name_corr}').uns
    control_err[item] = err
    control_corr[item] = corr

# %%
df_method_err = dict_to_pd(methods_err)
df_control_err = dict_to_pd(control_err)

# %%
df_method_corr = dict_to_pd(methods_corr)
df_control_corr = dict_to_pd(control_corr)

# %% [markdown]
# ## Mean rowwise error

# %% [markdown]
# ### Methods

# %%
df_method_err.sort_values(by="mean_rowwise_rmse")
# Out:
#                                                            dataset_id  \
# nn_retraining_with_pseudolabels                     neurips-2023-data
# nn_retraining_with_pseudolabels_embeddings_not_...  neurips-2023-data
# nn_retraining_with_pseudolabels_fingerprints_fp...  neurips-2023-data
# nn_retraining_with_pseudolabels_embeddings_dense    neurips-2023-data
# nn_retraining_with_pseudolabels_fingerprints_fp...  neurips-2023-data
# scape                                               neurips-2023-data
# lgc_ensemble_direct                                 neurips-2023-data
# pyboost                                             neurips-2023-data
# jn_ap_op2                                           neurips-2023-data
# transformer_ensemble                                neurips-2023-data
#
#                                                                           method_id  \
# nn_retraining_with_pseudolabels                     nn_retraining_with_pseudolabels
# nn_retraining_with_pseudolabels_embeddings_not_...  nn_retraining_with_pseudolabels
# nn_retraining_with_pseudolabels_fingerprints_fp...  nn_retraining_with_pseudolabels
# nn_retraining_with_pseudolabels_embeddings_dense    nn_retraining_with_pseudolabels
# nn_retraining_with_pseudolabels_fingerprints_fp...  nn_retraining_with_pseudolabels
# scape                                                                         scape
# lgc_ensemble_direct                                                    lgc_ensemble
# pyboost                                                                     pyboost
# jn_ap_op2                                                                 jn_ap_op2
# transformer_ensemble                                           transformer_ensemble
#
#                                                     mean_rowwise_rmse  \
# nn_retraining_with_pseudolabels                              0.755927
# nn_retraining_with_pseudolabels_embeddings_not_...           0.759375
# nn_retraining_with_pseudolabels_fingerprints_fp...           0.759427
# nn_retraining_with_pseudolabels_embeddings_dense             0.760094
# nn_retraining_with_pseudolabels_fingerprints_fp...           0.761362
# scape                                                        0.774636
# lgc_ensemble_direct                                          0.795568
# pyboost                                                      0.795777
# jn_ap_op2                                                    0.896406
# transformer_ensemble                                         0.899493
#
#                                                     mean_rowwise_mae
# nn_retraining_with_pseudolabels                             0.546358
# nn_retraining_with_pseudolabels_embeddings_not_...          0.547891
# nn_retraining_with_pseudolabels_fingerprints_fp...          0.550008
# nn_retraining_with_pseudolabels_embeddings_dense            0.551483
# nn_retraining_with_pseudolabels_fingerprints_fp...          0.554724
# scape                                                       0.571945
# lgc_ensemble_direct                                         0.578494
# pyboost                                                     0.560939
# jn_ap_op2                                                   0.652236
# transformer_ensemble                                        0.634239

# %% [markdown]
# ### Control methods

# %%
df_control_err.sort_values(by="mean_rowwise_rmse")
# Out:
#                               dataset_id              method_id  \
# ground_truth           neurips-2023-data           ground_truth
# mean_across_celltypes  neurips-2023-data  mean_across_celltypes
# mean_outcome           neurips-2023-data           mean_outcome
# zeros                  neurips-2023-data                  zeros
# mean_across_compounds  neurips-2023-data  mean_across_compounds
# sample                 neurips-2023-data                 sample
#
#                        mean_rowwise_rmse  mean_rowwise_mae
# ground_truth                    0.000000          0.000000
# mean_across_celltypes           0.892474          0.643716
# mean_outcome                    0.899233          0.635633
# zeros                           0.917925          0.635087
# mean_across_compounds           0.942813          0.697865
# sample                          1.363488          0.963245

# %% [markdown]
# ## Mean rowwise correlation

# %% [markdown]
# ### Methods

# %%
df_method_corr.sort_values(by="mean_rowwise_spearman", ascending=False)
# Out:
#                                                            dataset_id  \
# nn_retraining_with_pseudolabels                     neurips-2023-data
# nn_retraining_with_pseudolabels_embeddings_dense    neurips-2023-data
# nn_retraining_with_pseudolabels_embeddings_not_...  neurips-2023-data
# nn_retraining_with_pseudolabels_fingerprints_fp...  neurips-2023-data
# nn_retraining_with_pseudolabels_fingerprints_fp...  neurips-2023-data
# scape                                               neurips-2023-data
# pyboost                                             neurips-2023-data
# lgc_ensemble_direct                                 neurips-2023-data
# jn_ap_op2                                           neurips-2023-data
# transformer_ensemble                                neurips-2023-data
#
#                                                                           method_id  \
# nn_retraining_with_pseudolabels                     nn_retraining_with_pseudolabels
# nn_retraining_with_pseudolabels_embeddings_dense    nn_retraining_with_pseudolabels
# nn_retraining_with_pseudolabels_embeddings_not_...  nn_retraining_with_pseudolabels
# nn_retraining_with_pseudolabels_fingerprints_fp...  nn_retraining_with_pseudolabels
# nn_retraining_with_pseudolabels_fingerprints_fp...  nn_retraining_with_pseudolabels
# scape                                                                         scape
# pyboost                                                                     pyboost
# lgc_ensemble_direct                                                    lgc_ensemble
# jn_ap_op2                                                                 jn_ap_op2
# transformer_ensemble                                           transformer_ensemble
#
#                                                     mean_rowwise_pearson  \
# nn_retraining_with_pseudolabels                                 0.490362
# nn_retraining_with_pseudolabels_embeddings_dense                0.484197
# nn_retraining_with_pseudolabels_embeddings_not_...              0.484176
# nn_retraining_with_pseudolabels_fingerprints_fp...              0.482727
# nn_retraining_with_pseudolabels_fingerprints_fp...              0.481321
# scape                                                           0.472742
# pyboost                                                         0.460455
# lgc_ensemble_direct                                             0.450067
# jn_ap_op2                                                       0.326674
# transformer_ensemble                                            0.218039
#
#                                                     mean_rowwise_spearman  \
# nn_retraining_with_pseudolabels                                  0.462083
# nn_retraining_with_pseudolabels_embeddings_dense                 0.456996
# nn_retraining_with_pseudolabels_embeddings_not_...               0.456850
# nn_retraining_with_pseudolabels_fingerprints_fp...               0.454459
# nn_retraining_with_pseudolabels_fingerprints_fp...               0.453544
# scape                                                            0.441614
# pyboost                                                          0.438837
# lgc_ensemble_direct                                              0.423551
# jn_ap_op2                                                        0.304523
# transformer_ensemble                                             0.213368
#
#                                                     mean_rowwise_cosine
# nn_retraining_with_pseudolabels                                0.493576
# nn_retraining_with_pseudolabels_embeddings_dense               0.487342
# nn_retraining_with_pseudolabels_embeddings_not_...             0.487432
# nn_retraining_with_pseudolabels_fingerprints_fp...             0.485924
# nn_retraining_with_pseudolabels_fingerprints_fp...             0.484589
# scape                                                          0.475776
# pyboost                                                        0.463593
# lgc_ensemble_direct                                            0.453961
# jn_ap_op2                                                      0.329534
# transformer_ensemble                                           0.223590

# %% [markdown]
# ### Control methods

# %%
df_control_corr.sort_values(by="mean_rowwise_spearman", ascending=False)
# Out:
#                               dataset_id              method_id  \
# ground_truth           neurips-2023-data           ground_truth
# mean_across_celltypes  neurips-2023-data  mean_across_celltypes
# mean_across_compounds  neurips-2023-data  mean_across_compounds
# mean_outcome           neurips-2023-data           mean_outcome
# sample                 neurips-2023-data                 sample
# zeros                  neurips-2023-data                  zeros
#
#                        mean_rowwise_pearson  mean_rowwise_spearman  \
# ground_truth                            NaN               1.000000
# mean_across_celltypes              0.297152               0.280571
# mean_across_compounds              0.259385               0.242509
# mean_outcome                       0.219819               0.211683
# sample                             0.050696               0.054819
# zeros                              0.000000               0.000000
#
#                        mean_rowwise_cosine
# ground_truth                           NaN
# mean_across_celltypes             0.301747
# mean_across_compounds             0.262827
# mean_outcome                      0.226435
# sample                            0.053091
# zeros                             0.000000
