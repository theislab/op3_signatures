# %%
print(1)
# Out:
# 1

# %%
import anndata as ad
import os
import pandas as pd

# %% [markdown]
# ## Download results

# %%
def dict_to_pd(d):
    rows = []

    for outer_key, inner in d.items():
        row = {
            "dataset_id": inner["dataset_id"],
            "method_id": inner["method_id"],
        }
        
        # Use values from "d" as column names
        for col_name, value in zip(inner["metric_ids"], inner["metric_values"]):
            row[col_name] = value
            
        rows.append(row)
    
    df = pd.DataFrame(rows, index=d.keys())
    return df

# %%
control_path = '../../data/benchmark/results/metrics/control_methods/'
methods_path = '../../data/benchmark/results/metrics/methods/'

# %%
file_name_err = 'mean_rowwise_error.h5ad'
file_name_corr = 'mean_rowwise_correlation.h5ad'

# %%
methods_err = {}
methods_corr = {}
for item in os.listdir(methods_path):
    err = ad.read_h5ad(f'{methods_path}{item}/{file_name_err}').uns
    corr = ad.read_h5ad(f'{methods_path}{item}/{file_name_corr}').uns
    methods_err[item] = err
    methods_corr[item] = corr

# %%
control_err = {}
control_corr = {}
for item in os.listdir(control_path):
    err = ad.read_h5ad(f'{control_path}{item}/{file_name_err}').uns
    corr = ad.read_h5ad(f'{control_path}{item}/{file_name_corr}').uns
    control_err[item] = err
    control_corr[item] = corr

# %%
df_method_err = dict_to_pd(methods_err)
df_control_err = dict_to_pd(control_err)

# %%
df_method_corr = dict_to_pd(methods_corr)
df_control_corr = dict_to_pd(control_corr)

# %% [markdown]
# ## Mean rowwise error

# %% [markdown]
# ### Methods

# %% [markdown]
# * `nn_retraining_with_pseudolabels_mol_emb_subsample_lpm_concat_dense` - concatenation of fixed LPM embedding with 2 trainable specified in the initial architecture of the models: cell type and small molecule embeddings, before concatenation LPM embedding was projected with an additional Dense layer.
# * `nn_retraining_with_pseudolabels_mol_emb_subsample_fp_concat_not_dense` - concatenation of fixed ECFP:2 embedding with 2 trainable: cell type and small molecule embeddings, before concatenation **no** additional Dense layer was applied.
# * `nn_retraining_with_pseudolabels_mol_emb_subsample_fp_concat_dense` - concatenation of fixed ECFP:2 embedding with 2 trainable: cell type and small molecule embeddings, before concatenation ECFP:2 embedding was projected with an additional Dense layer.
# * `nn_retraining_with_pseudolabels_mol_emb_subsample_lpm_trainable` - small molecule unfreezed embedding was initialized with LPM embedding information and then projected with a Dense layer to match original `emb_out` dimentions.
# * `nn_retraining_with_pseudolabels_mol_emb_subsample_fp_fixed` - small molecule freezed embedding was initialized with ECFP:2 embedding information and then projected with a Dense layer to match original `emb_out` dimentions.
# * `nn_retraining_with_pseudolabels_mol_emb_subsample_fp_trainable` - small molecule unfreezed embedding was initialized with ECFP:2 embedding information and then projected with a Dense layer to match original `emb_out` dimentions.
# * `nn_retraining_with_pseudolabels_mol_emb_subsample_lpm_concat_not_dense` - concatenation of fixed LPM embedding with 2 trainable: cell type and small molecule embeddings, before concatenation **no** additional Dense layer was applied.
# * `nn_retraining_with_pseudolabels_mol_emb_subsample_none` - Original architecture of models without additional embedding information.
# * `nn_retraining_with_pseudolabels_mol_emb_subsample_lpm_fixed` - small molecule freezed embedding was initialized with LPM embedding information and then projected with a Dense layer to match original `emb_out` dimentions.

# %%
df_method_err[df_method_err.index.str.contains('_mol_emb_subsample')].sort_values(by="mean_rowwise_rmse")
# Out:
#                                                            dataset_id  \
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
#
#                                                                                             method_id  \
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_lpm_co...
# ...

# %% [markdown]
# ### Control methods

# %%
df_control_err.sort_values(by="mean_rowwise_rmse")
# Out:
#                               dataset_id              method_id  \
# ground_truth           neurips-2023-data           ground_truth
# mean_across_celltypes  neurips-2023-data  mean_across_celltypes
# mean_outcome           neurips-2023-data           mean_outcome
# zeros                  neurips-2023-data                  zeros
# mean_across_compounds  neurips-2023-data  mean_across_compounds
# sample                 neurips-2023-data                 sample
#
#                        mean_rowwise_rmse  mean_rowwise_mae
# ground_truth                    0.000000          0.000000
# mean_across_celltypes           0.892474          0.643716
# mean_outcome                    0.899233          0.635633
# zeros                           0.917925          0.635087
# mean_across_compounds           0.942813          0.697865
# sample                          1.363488          0.963245

# %% [markdown]
# ## Mean rowwise correlation

# %% [markdown]
# ### Methods

# %% [markdown]
# * `nn_retraining_with_pseudolabels_mol_emb_subsample_lpm_trainable` - small molecule unfreezed embedding was initialized with LPM embedding information and then projected with a Dense layer to match original `emb_out` dimentions.
# * `nn_retraining_with_pseudolabels_mol_emb_subsample_fp_trainable` - small molecule unfreezed embedding was initialized with ECFP:2 embedding information and then projected with a Dense layer to match original `emb_out` dimentions.
# * `nn_retraining_with_pseudolabels_mol_emb_subsample_none` - Original architecture of models without additional embedding information.
# * `nn_retraining_with_pseudolabels_mol_emb_subsample_lpm_concat_dense` - concatenation of fixed LPM embedding with 2 trainable specified in the initial architecture of the models: cell type and small molecule embeddings, before concatenation LPM embedding was projected with an additional Dense layer.
# * `nn_retraining_with_pseudolabels_mol_emb_subsample_fp_fixed` - small molecule freezed embedding was initialized with ECFP:2 embedding information and then projected with a Dense layer to match original `emb_out` dimentions.
# * `nn_retraining_with_pseudolabels_mol_emb_subsample_lpm_concat_not_dense` - concatenation of fixed LPM embedding with 2 trainable: cell type and small molecule embeddings, before concatenation **no** additional Dense layer was applied.
# * `nn_retraining_with_pseudolabels_mol_emb_subsample_fp_concat_dense` - concatenation of fixed ECFP:2 embedding with 2 trainable: cell type and small molecule embeddings, before concatenation ECFP:2 embedding was projected with an additional Dense layer.
# * `nn_retraining_with_pseudolabels_mol_emb_subsample_lpm_fixed` - small molecule freezed embedding was initialized with LPM embedding information and then projected with a Dense layer to match original `emb_out` dimentions.
# * `nn_retraining_with_pseudolabels_mol_emb_subsample_fp_concat_not_dense` - concatenation of fixed ECFP:2 embedding with 2 trainable: cell type and small molecule embeddings, before concatenation **no** additional Dense layer was applied.

# %%
df_method_corr[df_method_corr.index.str.contains('_mol_emb_subsample')].sort_values(by="mean_rowwise_spearman", ascending=False)
# Out:
#                                                            dataset_id  \
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
#
#                                                                                             method_id  \
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_lpm_tr...
# ...

# %% [markdown]
# ### Control methods

# %%
df_control_corr.sort_values(by="mean_rowwise_spearman", ascending=False)
# Out:
#                               dataset_id              method_id  \
# ground_truth           neurips-2023-data           ground_truth
# mean_across_celltypes  neurips-2023-data  mean_across_celltypes
# mean_across_compounds  neurips-2023-data  mean_across_compounds
# mean_outcome           neurips-2023-data           mean_outcome
# sample                 neurips-2023-data                 sample
# zeros                  neurips-2023-data                  zeros
#
#                        mean_rowwise_pearson  mean_rowwise_spearman  \
# ground_truth                            NaN               1.000000
# mean_across_celltypes              0.297152               0.280571
# mean_across_compounds              0.259385               0.242509
# mean_outcome                       0.219819               0.211683
# sample                             0.050696               0.054819
# zeros                              0.000000               0.000000
#
#                        mean_rowwise_cosine
# ...
