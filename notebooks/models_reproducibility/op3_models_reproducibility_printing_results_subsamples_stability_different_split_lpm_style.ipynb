# %%
import anndata as ad
import os
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Download results

# %%
def dict_to_pd(d):
    rows = []

    for outer_key, inner in d.items():
        row = {
            "dataset_id": inner["dataset_id"],
            "method_id": inner["method_id"],
        }
        
        # Use values from "d" as column names
        for col_name, value in zip(inner["metric_ids"], inner["metric_values"]):
            row[col_name] = value
            
        rows.append(row)
    
    df = pd.DataFrame(rows, index=d.keys())
    return df

# %%
methods_path = '../../data/benchmark/results/metrics/methods/'

# %%
os.listdir(methods_path + 'nn_retraining_with_pseudolabels_mol_emb_subsample_fp_trainable/stability')
# Out:
# ['seed_1',
#  'seed_11',
#  'seed_2',
#  'seed_3',
#  'seed_4',
#  'seed_10',
#  'seed_14',
#  'seed_12',
#  'seed_13',
#  'seed_0']

# %%
file_name_err = 'mean_rowwise_error.h5ad'
file_name_corr = 'mean_rowwise_correlation.h5ad'

# %%
methods_err = {}
methods_corr = {}
for item in os.listdir(methods_path):
    if 'mol_emb_subsample' in item:
        stability_path = methods_path + item + '/stability'
        for seed in os.listdir(stability_path):
            
            err = ad.read_h5ad(f'{stability_path}/{seed}/{file_name_err}').uns
            corr = ad.read_h5ad(f'{stability_path}/{seed}/{file_name_corr}').uns
            methods_err[item + '_' + seed] = err
            methods_corr[item + '_' + seed] = corr

# %%
df_method_err = dict_to_pd(methods_err)

# %%
df_method_corr = dict_to_pd(methods_corr)

# %%
df_method_err['method_name'] = df_method_err.index.str.split('_seed_').str[0]
df_method_err['seed'] = df_method_err.index.str.split('_seed_').str[1].astype(int)

# %%
df_method_corr['method_name'] = df_method_corr.index.str.split('_seed_').str[0]
df_method_corr['seed'] = df_method_corr.index.str.split('_seed_').str[1].astype(int)

# %% [markdown]
# ## Mean rowwise error

# %% [markdown]
# ### Methods

# %%
df_method_err.sort_values(by="mean_rowwise_rmse")
# Out:
#                                                            dataset_id  \
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# ...                                                               ...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
#
#                                                                                             method_id  \
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_fp_tra...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_fp_tra...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_fp_tra...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_fp_tra...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_fp_tra...
# ...                                                                                               ...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...   nn_retraining_with_pseudolabels_mol_emb_fp_fixed
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_lpm_fixed
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_lpm_fixed
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_lpm_fixed
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_lpm_fixed
#
#                                                     mean_rowwise_rmse  \
# nn_retraining_with_pseudolabels_mol_emb_subsamp...           0.868068
# nn_retraining_with_pseudolabels_mol_emb_subsamp...           0.868230
# nn_retraining_with_pseudolabels_mol_emb_subsamp...           0.868242
# nn_retraining_with_pseudolabels_mol_emb_subsamp...           0.868448
# nn_retraining_with_pseudolabels_mol_emb_subsamp...           0.868467
# ...                                                               ...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...           0.909873
# nn_retraining_with_pseudolabels_mol_emb_subsamp...           0.910790
# nn_retraining_with_pseudolabels_mol_emb_subsamp...           0.911429
# nn_retraining_with_pseudolabels_mol_emb_subsamp...           0.911600
# nn_retraining_with_pseudolabels_mol_emb_subsamp...           0.912146
#
#                                                     mean_rowwise_mae  \
# nn_retraining_with_pseudolabels_mol_emb_subsamp...          0.608000
# nn_retraining_with_pseudolabels_mol_emb_subsamp...          0.609343
# nn_retraining_with_pseudolabels_mol_emb_subsamp...          0.609416
# nn_retraining_with_pseudolabels_mol_emb_subsamp...          0.609354
# nn_retraining_with_pseudolabels_mol_emb_subsamp...          0.608692
# ...                                                              ...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...          0.651510
# nn_retraining_with_pseudolabels_mol_emb_subsamp...          0.649229
# nn_retraining_with_pseudolabels_mol_emb_subsamp...          0.649372
# nn_retraining_with_pseudolabels_mol_emb_subsamp...          0.650025
# nn_retraining_with_pseudolabels_mol_emb_subsamp...          0.650270
#
#                                                                                           method_name  \
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# ...                                                                                               ...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
#
#                                                     seed
# nn_retraining_with_pseudolabels_mol_emb_subsamp...    12
# nn_retraining_with_pseudolabels_mol_emb_subsamp...    10
# nn_retraining_with_pseudolabels_mol_emb_subsamp...    11
# nn_retraining_with_pseudolabels_mol_emb_subsamp...    13
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     1
# ...                                                  ...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...    14
# nn_retraining_with_pseudolabels_mol_emb_subsamp...    13
# nn_retraining_with_pseudolabels_mol_emb_subsamp...    14
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     0
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     1
#
# [80 rows x 6 columns]

# %%
metrics = ["mean_rowwise_rmse", "mean_rowwise_mae"]
fig, axes = plt.subplots(1, len(metrics), figsize=(6 * len(metrics), 5))
for ax, metric in zip(axes, metrics):
    # collect values per method, ordered by median
    methods_ordered = (
        df_method_err.groupby("method_name")[metric]
        .median()
        .sort_values()
        .index.tolist()
    )
    data_per_method = [
        df_method_err.loc[df_method_err["method_name"] == m, metric].values
        for m in methods_ordered
    ]
    bp = ax.boxplot(data_per_method, patch_artist=True, vert=True)
    ax.set_xticks(range(1, len(methods_ordered) + 1))
    ax.set_xticklabels(
        # strip the long common prefix for readability
        [m.replace("nn_retraining_with_pseudolabels_mol_emb_subsample_", "") for m in methods_ordered],
        rotation=45, ha="right", fontsize=8,
    )
    ax.set_ylabel(metric)
    ax.set_title(metric)
    ax.grid(axis="y", linestyle="--", alpha=0.5)
fig.suptitle("Stability across seeds", fontsize=13, y=1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Mean rowwise correlation

# %% [markdown]
# ### Methods

# %%
df_method_corr.sort_values(by="mean_rowwise_pearson", ascending=False)
#df_method_corr.sort_values(by="mean_rowwise_spearman", ascending=False)
# Out:
#                                                            dataset_id  \
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# ...                                                               ...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  neurips-2023-data
#
#                                                                                             method_id  \
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_fp_con...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_fp_con...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_fp_con...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_fp_con...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_fp_con...
# ...                                                                                               ...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_lpm_fixed
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_lpm_fixed
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_lpm_fixed
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_lpm_fixed
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_lpm_fixed
#
#                                                     mean_rowwise_pearson  \
# nn_retraining_with_pseudolabels_mol_emb_subsamp...              0.264112
# nn_retraining_with_pseudolabels_mol_emb_subsamp...              0.263683
# nn_retraining_with_pseudolabels_mol_emb_subsamp...              0.263093
# nn_retraining_with_pseudolabels_mol_emb_subsamp...              0.263068
# nn_retraining_with_pseudolabels_mol_emb_subsamp...              0.262644
# ...                                                                  ...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...              0.190546
# nn_retraining_with_pseudolabels_mol_emb_subsamp...              0.189650
# nn_retraining_with_pseudolabels_mol_emb_subsamp...              0.189339
# nn_retraining_with_pseudolabels_mol_emb_subsamp...              0.186447
# nn_retraining_with_pseudolabels_mol_emb_subsamp...              0.185004
#
#                                                     mean_rowwise_spearman  \
# nn_retraining_with_pseudolabels_mol_emb_subsamp...               0.254966
# nn_retraining_with_pseudolabels_mol_emb_subsamp...               0.254165
# nn_retraining_with_pseudolabels_mol_emb_subsamp...               0.253111
# nn_retraining_with_pseudolabels_mol_emb_subsamp...               0.253065
# nn_retraining_with_pseudolabels_mol_emb_subsamp...               0.252899
# ...                                                                   ...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...               0.184232
# nn_retraining_with_pseudolabels_mol_emb_subsamp...               0.183866
# nn_retraining_with_pseudolabels_mol_emb_subsamp...               0.183506
# nn_retraining_with_pseudolabels_mol_emb_subsamp...               0.179873
# nn_retraining_with_pseudolabels_mol_emb_subsamp...               0.178084
#
#                                                     mean_rowwise_cosine  \
# nn_retraining_with_pseudolabels_mol_emb_subsamp...             0.267722
# nn_retraining_with_pseudolabels_mol_emb_subsamp...             0.267333
# nn_retraining_with_pseudolabels_mol_emb_subsamp...             0.266717
# nn_retraining_with_pseudolabels_mol_emb_subsamp...             0.266688
# nn_retraining_with_pseudolabels_mol_emb_subsamp...             0.266241
# ...                                                                 ...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...             0.194329
# nn_retraining_with_pseudolabels_mol_emb_subsamp...             0.193403
# nn_retraining_with_pseudolabels_mol_emb_subsamp...             0.193159
# nn_retraining_with_pseudolabels_mol_emb_subsamp...             0.190211
# nn_retraining_with_pseudolabels_mol_emb_subsamp...             0.188633
#
#                                                                                           method_name  \
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# ...                                                                                               ...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...  nn_retraining_with_pseudolabels_mol_emb_subsam...
#
#                                                     seed
# nn_retraining_with_pseudolabels_mol_emb_subsamp...    14
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     4
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     0
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     3
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     1
# ...                                                  ...
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     0
# nn_retraining_with_pseudolabels_mol_emb_subsamp...    14
# nn_retraining_with_pseudolabels_mol_emb_subsamp...    12
# nn_retraining_with_pseudolabels_mol_emb_subsamp...    13
# nn_retraining_with_pseudolabels_mol_emb_subsamp...     1
#
# [80 rows x 7 columns]

# %%
corr_metrics = ["mean_rowwise_pearson", "mean_rowwise_spearman", "mean_rowwise_cosine"]
fig, axes = plt.subplots(1, len(corr_metrics), figsize=(6 * len(corr_metrics), 5))
for ax, metric in zip(axes, corr_metrics):
    # higher correlation is better → sort descending
    methods_ordered = (
        df_method_corr.groupby("method_name")[metric]
        .median()
        .sort_values(ascending=False)
        .index.tolist()
    )
    data_per_method = [
        df_method_corr.loc[df_method_corr["method_name"] == m, metric].values
        for m in methods_ordered
    ]
    bp = ax.boxplot(data_per_method, patch_artist=True, vert=True)
    ax.set_xticks(range(1, len(methods_ordered) + 1))
    ax.set_xticklabels(
        [m.replace("nn_retraining_with_pseudolabels_mol_emb_subsample_", "") for m in methods_ordered],
        rotation=45, ha="right", fontsize=8,
    )
    ax.set_ylabel(metric)
    ax.set_title(metric)
    ax.grid(axis="y", linestyle="--", alpha=0.5)
fig.suptitle("Stability across seeds — correlations", fontsize=13, y=1.02)
plt.tight_layout()
plt.show()
